# %%
# Test fractal_cloud_generator

# %%
import h5py, os
import numpy as np
import matplotlib.pyplot as plt

# %%
from fractal_cloud_generation import frac_physics

# %%
fcld = frac_physics('test.nc')

# %%
#Constants 
fcld.f = 0.37
re = 12.0 # Effective radius microns
lwp = 90 #gm^{-2}

# %%
fcld.generate_fractal(re,lwp,xorder=12,xdist=40.0)

# %%
fcld.plot_lwp_pdf()
# Out:
# C:\Users\Scott\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# (<matplotlib.figure.Figure at 0x26fc757c9b0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x26fc76e45f8>)

# %%
fcld.plot_cld()
# Out:
# C:\Users\Scott\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fcld.save_frach5('test.nc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-325805ff5890> in <module>()
# ----> 1 fcld.save_frach5('test.nc')
#
# ~\Dropbox\Math\CyberTraining_Class\Project\Code\fractal_cloud_generation.py in save_frach5(self, fname)
#      64
#      65         if os.path.isfile(self.fname):
# ---> 66             rd=raw_input('File already exist. Replace?: ')
#      67         else:
#      68             rd='y'
#
# NameError: name 'raw_input' is not defined

# %%
# Look at data

# %%
#import mpl_toolkits.basemap as bm
from netCDF4 import Dataset
import matplotlib as mpl
#import mpl_toolkits.basemap as bm
mpl.rc('font',family='Times New Roman')

# %%
dataset = Dataset('test.nc')
print(dataset.variables.keys())
# Out:
# odict_keys(['f', 'lwp', 'orderX', 're', 'tau', 'x', 'y'])

# %%
print(dataset.variables['f'])
print(dataset.variables['lwp'])
print(dataset.variables['orderX'])
print(dataset.variables['re'])
print(dataset.variables['tau'])
print(dataset.variables['x'])
print(dataset.variables['y'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 f()
# unlimited dimensions:
# current shape = ()
# filling off
#
# <class 'netCDF4._netCDF4.Variable'>
# float64 lwp(phony_dim_0)
#     DIMENSION_LABELS: x
#     long_name: liquid_water_path
#     unit: g/m^2
# unlimited dimensions:
# current shape = (4096,)
# filling off
#
# <class 'netCDF4._netCDF4.Variable'>
# int64 orderX()
#     long_name: x_dimension_order
# unlimited dimensions:
# current shape = ()
# filling off
#
# <class 'netCDF4._netCDF4.Variable'>
# float64 re(phony_dim_0)
#     DIMENSION_LABELS: x
#     long_name: effective_radius
#     unit: microns
# unlimited dimensions:
# current shape = (4096,)
# filling off
#
# <class 'netCDF4._netCDF4.Variable'>
# float64 tau(phony_dim_0)
#     DIMENSION_LABELS: x
#     long_name: Cloud_optical_thickness
# unlimited dimensions:
# current shape = (4096,)
# filling off
#
# <class 'netCDF4._netCDF4.Variable'>
# float64 x(phony_dim_0)
#     long_name: x_dimension
#     unit: km
# ...

# %%
# Extract values from data set
optical_thickness = dataset.variables['tau'][:]
effective_radius = dataset.variables['re'][:]
liquid_water_path = dataset.variables['lwp'][:]

# %%
for i in range(0,10):
    print(liquid_water_path[i])
# Out:
# 79.8477168785265
# 73.27130496633463
# 88.90770458091394
# 81.58509461347977
# 83.81305812559773
# 91.33563731410356
# 101.69911147723315
# 93.32297657539638
# 75.1458914961091
# 68.95673098774904

# %%
for i in range(0,10):
    print(effective_radius[i])
